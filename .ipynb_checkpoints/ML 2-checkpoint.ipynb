# %%
import pandas
df = pandas.read_csv(r'.\fake.csv')
print(df)
# Out:
#                                            uuid  ord_in_thread  \
# 0      6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1      2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2      c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3      7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4      0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
# ...                                         ...            ...
# 12994  f1b5d0e44803f48732bde854a9fdf95837219b12              2
# 12995  36011ceba3647e1bea78299b68b6fb705a1fc1ad              3
# 12996  6995d1aa9ac99926106489b14b5530e85358059a              4
# 12997  7de8ae90eee164eb756db6c8a3772288e11d7a94              5
# 12998  dabef7095b7d9dae6eb0d83c4cbb40b85efd7ae5              6
#
#                      author                      published  \
# 0         Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1      reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2         Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                    Fed Up  2016-11-01T05:22:00.000+02:00
# 4                    Fed Up  2016-11-01T21:56:00.000+02:00
# ...                     ...                            ...
# 12994             replaceme  2016-10-26T23:58:00.000+03:00
# 12995              Freedumb  2016-10-27T00:02:00.000+03:00
# 12996    major major maj...  2016-10-27T00:06:00.000+03:00
# 12997            beemasters  2016-10-27T00:09:00.000+03:00
# 12998     i&#039;m-confused  2016-10-27T00:09:00.000+03:00
#
#                                                    title  \
# 0      Muslims BUSTED: They Stole Millions In Gov’t B...
# 1      Re: Why Did Attorney General Loretta Lynch Ple...
# 2      BREAKING: Weiner Cooperating With FBI On Hilla...
# 3      PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4      FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
# ...                                                  ...
# 12994                                                NaN
# 12995                                                NaN
# 12996                                                NaN
# 12997                                                NaN
# 12998                                                NaN
#
#                                                     text language  \
# 0      Print They should pay all the back all the mon...  english
# 1      Why Did Attorney General Loretta Lynch Plead T...  english
# 2      Red State : \nFox News Sunday reported this mo...  english
# 3      Email Kayla Mueller was a prisoner and torture...  english
# 4      Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  english
# ...                                                  ...      ...
# 12994  It DOES allow you to put a dog face on top of ...  english
# 12995  Wait till you see what happens to the valuatio...  english
# 12996  I'm waiting for the one that puts a pussy on m...  english
# 12997  $4 Billion even after they are known to be kee...  english
# 12998  of course - how else would they disceminate te...  english
#
#                              crawled             site_url country  \
# 0      2016-10-27T01:49:27.168+03:00  100percentfedup.com      US
# 1      2016-10-29T08:47:11.259+03:00  100percentfedup.com      US
# 2      2016-10-31T01:41:49.479+02:00  100percentfedup.com      US
# 3      2016-11-01T15:46:26.304+02:00  100percentfedup.com      US
# 4      2016-11-01T23:59:42.266+02:00  100percentfedup.com      US
# ...                              ...                  ...     ...
# 12994  2016-10-27T00:37:46.194+03:00        zerohedge.com      US
# 12995  2016-10-27T00:37:46.220+03:00        zerohedge.com      US
# 12996  2016-10-27T00:37:46.244+03:00        zerohedge.com      US
# 12997  2016-10-27T00:37:46.247+03:00        zerohedge.com      US
# 12998  2016-10-27T00:37:46.260+03:00        zerohedge.com      US
#
#        domain_rank                                       thread_title  \
# 0          25689.0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1          25689.0  Re: Why Did Attorney General Loretta Lynch Ple...
# 2          25689.0  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3          25689.0  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4          25689.0  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
# ...            ...                                                ...
# 12994       2435.0  Snapchat To Raise Up To $4 Billion In IPO, Val...
# 12995       2435.0  Snapchat To Raise Up To $4 Billion In IPO, Val...
# 12996       2435.0  Snapchat To Raise Up To $4 Billion In IPO, Val...
# 12997       2435.0  Snapchat To Raise Up To $4 Billion In IPO, Val...
# 12998       2435.0  Snapchat To Raise Up To $4 Billion In IPO, Val...
#
#        spam_score                                       main_img_url  \
# 0           0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 1           0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 2           0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 3           0.068  http://100percentfedup.com/wp-content/uploads/...
# 4           0.865  http://100percentfedup.com/wp-content/uploads/...
# ...           ...                                                ...
# 12994       0.000                                                NaN
# 12995       0.000                                                NaN
# 12996       0.000                                                NaN
# 12997       0.000                                                NaN
# 12998       0.000                                                NaN
#
#        replies_count  participants_count  likes  comments  shares  type
# 0                  0                   1      0         0       0  bias
# 1                  0                   1      0         0       0  bias
# 2                  0                   1      0         0       0  bias
# 3                  0                   0      0         0       0  bias
# 4                  0                   0      0         0       0  bias
# ...              ...                 ...    ...       ...     ...   ...
# 12994             40                  32      0         0       0    bs
# 12995             40                  32      0         0       0    bs
# 12996             40                  32      0         0       0    bs
# 12997             40                  32      0         0       0    bs
# 12998             40                  32      0         0       0    bs
#
# [12999 rows x 20 columns]

# %%
import scipy as sp

# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df, figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='ord_in_thread', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='likes', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='comments', ylabel='ord_in_thread'>,
#         <AxesSubplot:xlabel='shares', ylabel='ord_in_thread'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='likes', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='comments', ylabel='domain_rank'>,
#         <AxesSubplot:xlabel='shares', ylabel='domain_rank'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='likes', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='comments', ylabel='spam_score'>,
#         <AxesSubplot:xlabel='shares', ylabel='spam_score'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='likes', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='comments', ylabel='replies_count'>,
#         <AxesSubplot:xlabel='shares', ylabel='replies_count'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='likes', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='comments', ylabel='participants_count'>,
#         <AxesSubplot:xlabel='shares', ylabel='participants_count'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='likes'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='likes'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='likes'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='likes'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='likes'>,
#         <AxesSubplot:xlabel='likes', ylabel='likes'>,
#         <AxesSubplot:xlabel='comments', ylabel='likes'>,
#         <AxesSubplot:xlabel='shares', ylabel='likes'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='comments'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='comments'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='comments'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='comments'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='comments'>,
#         <AxesSubplot:xlabel='likes', ylabel='comments'>,
#         <AxesSubplot:xlabel='comments', ylabel='comments'>,
#         <AxesSubplot:xlabel='shares', ylabel='comments'>],
#        [<AxesSubplot:xlabel='ord_in_thread', ylabel='shares'>,
#         <AxesSubplot:xlabel='domain_rank', ylabel='shares'>,
#         <AxesSubplot:xlabel='spam_score', ylabel='shares'>,
#         <AxesSubplot:xlabel='replies_count', ylabel='shares'>,
#         <AxesSubplot:xlabel='participants_count', ylabel='shares'>,
#         <AxesSubplot:xlabel='likes', ylabel='shares'>,
#         <AxesSubplot:xlabel='comments', ylabel='shares'>,
#         <AxesSubplot:xlabel='shares', ylabel='shares'>]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   uuid                12999 non-null  object
#  1   ord_in_thread       12999 non-null  int64
#  2   author              10575 non-null  object
#  3   published           12999 non-null  object
#  4   title               12319 non-null  object
#  5   text                12953 non-null  object
#  6   language            12999 non-null  object
#  7   crawled             12999 non-null  object
#  8   site_url            12999 non-null  object
#  9   country             12823 non-null  object
#  10  domain_rank         8776 non-null   float64
#  11  thread_title        12987 non-null  object
#  12  spam_score          12999 non-null  float64
#  13  main_img_url        9356 non-null   object
#  14  replies_count       12999 non-null  int64
#  15  participants_count  12999 non-null  int64
#  16  likes               12999 non-null  int64
#  17  comments            12999 non-null  int64
#  18  shares              12999 non-null  int64
#  19  type                12999 non-null  object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
# 2  Red State : \nFox News Sunday reported this mo...  english
# 3  Email Kayla Mueller was a prisoner and torture...  english
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  english
#
#                          crawled             site_url country  domain_rank  \
# 0  2016-10-27T01:49:27.168+03:00  100percentfedup.com      US      25689.0
# 1  2016-10-29T08:47:11.259+03:00  100percentfedup.com      US      25689.0
# 2  2016-10-31T01:41:49.479+02:00  100percentfedup.com      US      25689.0
# 3  2016-11-01T15:46:26.304+02:00  100percentfedup.com      US      25689.0
# 4  2016-11-01T23:59:42.266+02:00  100percentfedup.com      US      25689.0
#
#                                         thread_title  spam_score  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...       0.000
# 1  Re: Why Did Attorney General Loretta Lynch Ple...       0.000
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...       0.000
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...       0.068
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...       0.865
#
#                                         main_img_url  replies_count  \
# 0  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 1  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 2  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 3  http://100percentfedup.com/wp-content/uploads/...              0
# 4  http://100percentfedup.com/wp-content/uploads/...              0
#
#    participants_count  likes  comments  shares  type
# 0                   1      0         0       0  bias
# 1                   1      0         0       0  bias
# 2                   1      0         0       0  bias
# 3                   0      0         0       0  bias
# 4                   0      0         0       0  bias

# %%
df.describe()
# Out:
#        ord_in_thread   domain_rank    spam_score  replies_count  \
# count   12999.000000   8776.000000  12999.000000   12999.000000
# mean        0.891530  38092.996582      0.026122       1.383183
# std         6.486822  26825.487454      0.122889       9.656838
# min         0.000000    486.000000      0.000000       0.000000
# 25%         0.000000  17423.000000      0.000000       0.000000
# 50%         0.000000  34478.000000      0.000000       0.000000
# 75%         0.000000  60570.000000      0.000000       0.000000
# max       100.000000  98679.000000      1.000000     309.000000
#
#        participants_count         likes      comments        shares
# count        12999.000000  12999.000000  12999.000000  12999.000000
# mean             1.727518     10.831833      0.038311     10.831833
# std              6.884239     79.798949      0.827335     79.798949
# min              0.000000      0.000000      0.000000      0.000000
# 25%              1.000000      0.000000      0.000000      0.000000
# 50%              1.000000      0.000000      0.000000      0.000000
# 75%              1.000000      0.000000      0.000000      0.000000
# max            240.000000    988.000000     65.000000    988.000000

# %%
df_without_columns = df.drop(['uuid', 'main_img_url', 'type'], axis=1)
df_without_type = df.drop(['type'],  axis=1)
df_without_null_rows = df.dropna()

df_test = df.drop(['uuid', 'main_img_url', 'published', 'title', 'text','crawled',
                   'thread_title'], axis=1)
df_test = df_test.dropna()

from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df_test['country'])
df_test['country'] = enc.transform(df_test['country'])
enc.fit(df_test['language'])
df_test['language'] = enc.transform(df_test['language'])
enc.fit(df_test['author'])
df_test['author'] = enc.transform(df_test['author'])
enc.fit(df_test['site_url'])
df_test['site_url'] = enc.transform(df_test['site_url'])
enc.fit(df_test['type'])
df_test['type'] = enc.transform(df_test['type'])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6818 entries, 0 to 12998
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ord_in_thread       6818 non-null   int64
#  1   author              6818 non-null   int32
#  2   language            6818 non-null   int32
#  3   site_url            6818 non-null   int32
#  4   country             6818 non-null   int32
#  5   domain_rank         6818 non-null   float64
#  6   spam_score          6818 non-null   float64
#  7   replies_count       6818 non-null   int64
#  8   participants_count  6818 non-null   int64
#  9   likes               6818 non-null   int64
#  10  comments            6818 non-null   int64
#  11  shares              6818 non-null   int64
#  12  type                6818 non-null   int32
# dtypes: float64(2), int32(5), int64(6)
# memory usage: 612.6 KB

# %%
df_without_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   uuid                12999 non-null  object
#  1   ord_in_thread       12999 non-null  int64
#  2   author              10575 non-null  object
#  3   published           12999 non-null  object
#  4   title               12319 non-null  object
#  5   text                12953 non-null  object
#  6   language            12999 non-null  object
#  7   crawled             12999 non-null  object
#  8   site_url            12999 non-null  object
#  9   country             12823 non-null  object
#  10  domain_rank         8776 non-null   float64
#  11  thread_title        12987 non-null  object
#  12  spam_score          12999 non-null  float64
#  13  main_img_url        9356 non-null   object
#  14  replies_count       12999 non-null  int64
#  15  participants_count  12999 non-null  int64
#  16  likes               12999 non-null  int64
#  17  comments            12999 non-null  int64
#  18  shares              12999 non-null  int64
# dtypes: float64(2), int64(6), object(11)
# memory usage: 1.9+ MB

# %%
df_without_null_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4702 entries, 0 to 12898
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   uuid                4702 non-null   object
#  1   ord_in_thread       4702 non-null   int64
#  2   author              4702 non-null   object
#  3   published           4702 non-null   object
#  4   title               4702 non-null   object
#  5   text                4702 non-null   object
#  6   language            4702 non-null   object
#  7   crawled             4702 non-null   object
#  8   site_url            4702 non-null   object
#  9   country             4702 non-null   object
#  10  domain_rank         4702 non-null   float64
#  11  thread_title        4702 non-null   object
#  12  spam_score          4702 non-null   float64
#  13  main_img_url        4702 non-null   object
#  14  replies_count       4702 non-null   int64
#  15  participants_count  4702 non-null   int64
#  16  likes               4702 non-null   int64
#  17  comments            4702 non-null   int64
#  18  shares              4702 non-null   int64
#  19  type                4702 non-null   object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 771.4+ KB

# %%
df_without_null_rows.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'ord_in_thread'}>,
#         <AxesSubplot:title={'center':'domain_rank'}>,
#         <AxesSubplot:title={'center':'spam_score'}>],
#        [<AxesSubplot:title={'center':'replies_count'}>,
#         <AxesSubplot:title={'center':'participants_count'}>,
#         <AxesSubplot:title={'center':'likes'}>],
#        [<AxesSubplot:title={'center':'comments'}>,
#         <AxesSubplot:title={'center':'shares'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.metrics import davies_bouldin_score
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform(df_test)

wcss=[]
sil_score_max = -1 #this is the minimum possible score
kmeans = None
y_kmeans = None

def plot(self):
        fig, ax = plt.subplots(figsize=(12, 8))

        for i, index in enumerate(self.clusters):
            point = self.X[index].T
            ax.scatter(*point)

        for point in self.centroids:
            ax.scatter(*point, marker="x", color='black', linewidth=2)

        plt.show()

for n_clusters in range(2,20):
  model = KMeans(n_clusters = n_clusters, init='k-means++', max_iter=100, n_init=1)
  labels = model.fit_predict(df_test)
  print("Calinski Harabasz score: %f" %(metrics.calinski_harabasz_score(X, labels)))
  print("Davies Boudin score: %f" %(metrics.davies_bouldin_score(X, labels)))
  if n_clusters == 2:
    kmeans = model
    y_kmeans = labels
    #plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis');
  sil_score = silhouette_score(df_test, labels)
  print("Without columns: The average silhouette score for %i clusters is %0.2f" %(n_clusters,sil_score))
  print("-------------------------------------------------------------------")
  wcss.append(model.inertia_)
  if sil_score > sil_score_max:
    sil_score_max = sil_score
    best_n_clusters = n_clusters
# Out:
# Calinski Harabasz score: 491.725215
# Davies Boudin score: 2.518957
# Without columns: The average silhouette score for 2 clusters is 0.64
# -------------------------------------------------------------------
# Calinski Harabasz score: 326.046469
# Davies Boudin score: 3.587417
# Without columns: The average silhouette score for 3 clusters is 0.57
# -------------------------------------------------------------------
# Calinski Harabasz score: 248.208080
# Davies Boudin score: 3.700494
# Without columns: The average silhouette score for 4 clusters is 0.62
# -------------------------------------------------------------------
# Calinski Harabasz score: 191.565408
# Davies Boudin score: 4.359339
# Without columns: The average silhouette score for 5 clusters is 0.60
# -------------------------------------------------------------------
# Calinski Harabasz score: 180.776052
# Davies Boudin score: 4.463259
# Without columns: The average silhouette score for 6 clusters is 0.64
# -------------------------------------------------------------------
# Calinski Harabasz score: 150.339765
# Davies Boudin score: 4.438305
# Without columns: The average silhouette score for 7 clusters is 0.65
# -------------------------------------------------------------------
# Calinski Harabasz score: 153.569991
# Davies Boudin score: 4.382430
# Without columns: The average silhouette score for 8 clusters is 0.64
# -------------------------------------------------------------------
# Calinski Harabasz score: 152.056655
# Davies Boudin score: 3.969563
# Without columns: The average silhouette score for 9 clusters is 0.63
# -------------------------------------------------------------------
# Calinski Harabasz score: 127.328851
# Davies Boudin score: 4.665979
# Without columns: The average silhouette score for 10 clusters is 0.61
# -------------------------------------------------------------------
# Calinski Harabasz score: 125.163509
# Davies Boudin score: 4.614985
# Without columns: The average silhouette score for 11 clusters is 0.61
# -------------------------------------------------------------------
# Calinski Harabasz score: 112.293395
# Davies Boudin score: 4.394363
# Without columns: The average silhouette score for 12 clusters is 0.62
# -------------------------------------------------------------------
# Calinski Harabasz score: 111.119037
# Davies Boudin score: 3.906114
# Without columns: The average silhouette score for 13 clusters is 0.63
# -------------------------------------------------------------------
# Calinski Harabasz score: 111.578606
# Davies Boudin score: 4.050752
# Without columns: The average silhouette score for 14 clusters is 0.62
# -------------------------------------------------------------------
# Calinski Harabasz score: 100.968883
# Davies Boudin score: 4.232974
# Without columns: The average silhouette score for 15 clusters is 0.61
# -------------------------------------------------------------------
# Calinski Harabasz score: 98.678677
# Davies Boudin score: 4.222039
# Without columns: The average silhouette score for 16 clusters is 0.64
# -------------------------------------------------------------------
# Calinski Harabasz score: 94.919494
# Davies Boudin score: 4.060659
# Without columns: The average silhouette score for 17 clusters is 0.65
# -------------------------------------------------------------------
# Calinski Harabasz score: 90.481029
# Davies Boudin score: 3.597915
# Without columns: The average silhouette score for 18 clusters is 0.63
# -------------------------------------------------------------------
# Calinski Harabasz score: 94.469942
# Davies Boudin score: 3.490068
# Without columns: The average silhouette score for 19 clusters is 0.63
# -------------------------------------------------------------------

# %%
print(df_test.shape[0])
print(y_kmeans.shape[0])
fakeCount =0
bs0 = 0
bs1 = 0
fake0 = 0
fake1 = 0
consp0 = 0
consp1 = 0
bias0 = 0
bias1 = 0


for index, row in df.iterrows():
    if(index < df_test.shape[0]):
        print("%i) Predicted value %s, actual value %s" %(index,y_kmeans[index], row['type']))
        if(row['type'] == 'fake'):
            fakeCount = fakeCount + 1
            if(y_kmeans[index] == 0):
                fake0 = fake0 + 1
            else:
                fake1 = fake1 + 1
        elif row['type'] == 'bs':
            if(y_kmeans[index] == 0):
                bs0 = bs0 + 1
            else:
                bs1 = bs1 + 1
        elif row['type'] == 'conspiracy':
            if(y_kmeans[index] == 0):
                consp0 = consp0 + 1
            else:
                consp1 = consp1 + 1
        elif row['type'] == 'bias':
            if(y_kmeans[index] == 0):
                bias0 = bias0 + 1
            else:
                bias1 = bias1 + 1
            
print("bias 1 %i" %(bias1))
print("bias 0 %i" %(bias0))
print("bs 1 %i" %(bs1))
print("bs 0 %i" %(bs0))
print("consp 1 %i" %(consp1))
print("consp 0 %i" %(consp0))
print("FAKE count %i" %(fakeCount))            
print("FAKE 1 %i" %(fake1))
print("FAKE 0 %i" %(fake0))        
    
#for ind in range(1,df_test.shape[0]):
#    print("%i) Predicted value %s, actual value %s" %(ind,y_kmeans[ind], df_test[[ind, 'type']]))
# Out:
# 6818
# 6818
# 0) Predicted value 1, actual value bias
# 1) Predicted value 1, actual value bias
# 2) Predicted value 1, actual value bias
# 3) Predicted value 1, actual value bias
# 4) Predicted value 1, actual value bias
# 5) Predicted value 1, actual value bias
# 6) Predicted value 1, actual value bias
# 7) Predicted value 1, actual value bias
# 8) Predicted value 1, actual value bias
# 9) Predicted value 1, actual value bias
# 10) Predicted value 1, actual value bias
# 11) Predicted value 1, actual value bias
# 12) Predicted value 1, actual value bias
# 13) Predicted value 1, actual value bias
# 14) Predicted value 1, actual value bias
# 15) Predicted value 1, actual value bias
# 16) Predicted value 1, actual value bias
# 17) Predicted value 1, actual value bias
# 18) Predicted value 1, actual value bias
# 19) Predicted value 1, actual value bias
# 20) Predicted value 1, actual value bias
# 21) Predicted value 1, actual value bias
# 22) Predicted value 1, actual value bias
# 23) Predicted value 1, actual value bias
# 24) Predicted value 1, actual value bias
# 25) Predicted value 1, actual value bias
# 26) Predicted value 1, actual value bias
# 27) Predicted value 1, actual value bias
# 28) Predicted value 1, actual value bias
# 29) Predicted value 1, actual value bias
# 30) Predicted value 1, actual value bias
# 31) Predicted value 1, actual value bias
# 32) Predicted value 1, actual value bias
# 33) Predicted value 0, actual value conspiracy
# 34) Predicted value 0, actual value conspiracy
# 35) Predicted value 1, actual value conspiracy
# 36) Predicted value 1, actual value conspiracy
# 37) Predicted value 1, actual value conspiracy
# 38) Predicted value 1, actual value conspiracy
# 39) Predicted value 1, actual value conspiracy
# 40) Predicted value 1, actual value conspiracy
# 41) Predicted value 1, actual value conspiracy
# 42) Predicted value 1, actual value conspiracy
# 43) Predicted value 1, actual value conspiracy
# 44) Predicted value 1, actual value conspiracy
# 45) Predicted value 1, actual value conspiracy
# 46) Predicted value 1, actual value conspiracy
# 47) Predicted value 1, actual value conspiracy
# 48) Predicted value 1, actual value conspiracy
# 49) Predicted value 1, actual value conspiracy
# 50) Predicted value 1, actual value conspiracy
# 51) Predicted value 1, actual value conspiracy
# 52) Predicted value 1, actual value conspiracy
# 53) Predicted value 1, actual value conspiracy
# 54) Predicted value 1, actual value conspiracy
# 55) Predicted value 1, actual value conspiracy
# 56) Predicted value 1, actual value conspiracy
# 57) Predicted value 1, actual value fake
# 58) Predicted value 1, actual value fake
# 59) Predicted value 1, actual value bs
# 60) Predicted value 1, actual value bs
# 61) Predicted value 1, actual value bs
# 62) Predicted value 1, actual value bs
# 63) Predicted value 1, actual value bs
# 64) Predicted value 1, actual value bs
# 65) Predicted value 1, actual value bs
# 66) Predicted value 1, actual value bs
# 67) Predicted value 1, actual value bs
# 68) Predicted value 1, actual value bs
# 69) Predicted value 1, actual value bs
# 70) Predicted value 1, actual value bs
# 71) Predicted value 1, actual value bs
# 72) Predicted value 1, actual value bs
# 73) Predicted value 1, actual value bs
# 74) Predicted value 1, actual value bs
# 75) Predicted value 1, actual value bs
# 76) Predicted value 1, actual value bs
# 77) Predicted value 1, actual value bs
# 78) Predicted value 1, actual value bs
# 79) Predicted value 1, actual value bs
# 80) Predicted value 1, actual value bs
# 81) Predicted value 1, actual value bs
# 82) Predicted value 1, actual value bs
# 83) Predicted value 1, actual value bs
# 84) Predicted value 1, actual value bs
# 85) Predicted value 1, actual value bs
# 86) Predicted value 1, actual value bs
# 87) Predicted value 1, actual value bs
# 88) Predicted value 1, actual value bs
# 89) Predicted value 1, actual value bs
# 90) Predicted value 1, actual value bs
# 91) Predicted value 1, actual value bs
# 92) Predicted value 1, actual value bs
# 93) Predicted value 1, actual value bs
# 94) Predicted value 1, actual value bs
# 95) Predicted value 1, actual value bs
# 96) Predicted value 1, actual value bs
# 97) Predicted value 1, actual value bs
# 98) Predicted value 1, actual value bs
# 99) Predicted value 1, actual value bs
# 100) Predicted value 1, actual value bs
# 101) Predicted value 1, actual value bs
# 102) Predicted value 1, actual value bs
# 103) Predicted value 1, actual value bs
# 104) Predicted value 1, actual value bs
# 105) Predicted value 1, actual value bs
# 106) Predicted value 1, actual value bs
# 107) Predicted value 1, actual value bs
# 108) Predicted value 1, actual value bs
# 109) Predicted value 1, actual value bs
# 110) Predicted value 1, actual value bs
# 111) Predicted value 1, actual value bs
# 112) Predicted value 1, actual value bs
# 113) Predicted value 1, actual value bs
# 114) Predicted value 1, actual value bs
# 115) Predicted value 1, actual value bs
# 116) Predicted value 1, actual value bs
# 117) Predicted value 1, actual value bs
# 118) Predicted value 1, actual value bs
# 119) Predicted value 1, actual value bs
# 120) Predicted value 1, actual value bs
# 121) Predicted value 1, actual value bs
# 122) Predicted value 1, actual value bs
# 123) Predicted value 1, actual value bs
# 124) Predicted value 1, actual value bs
# 125) Predicted value 1, actual value bs
# 126) Predicted value 1, actual value bs
# 127) Predicted value 1, actual value bs
# 128) Predicted value 1, actual value bs
# 129) Predicted value 1, actual value bs
# 130) Predicted value 1, actual value bs
# 131) Predicted value 1, actual value bs
# 132) Predicted value 1, actual value bs
# 133) Predicted value 1, actual value bs
# 134) Predicted value 1, actual value bs
# 135) Predicted value 1, actual value bs
# 136) Predicted value 1, actual value bs
# 137) Predicted value 1, actual value bs
# 138) Predicted value 1, actual value bs
# 139) Predicted value 1, actual value bs
# 140) Predicted value 1, actual value bs
# 141) Predicted value 1, actual value bs
# 142) Predicted value 1, actual value bs
# 143) Predicted value 1, actual value bs
# 144) Predicted value 1, actual value bs
# 145) Predicted value 1, actual value bs
# 146) Predicted value 1, actual value bs
# 147) Predicted value 1, actual value bs
# 148) Predicted value 1, actual value bs
# 149) Predicted value 1, actual value bs
# 150) Predicted value 1, actual value bs
# 151) Predicted value 1, actual value bs
# 152) Predicted value 1, actual value bs
# 153) Predicted value 1, actual value bs
# 154) Predicted value 1, actual value bs
# 155) Predicted value 1, actual value bs
# 156) Predicted value 1, actual value bs
# 157) Predicted value 1, actual value bs
# 158) Predicted value 1, actual value bs
# 159) Predicted value 1, actual value bs
# 160) Predicted value 1, actual value bs
# 161) Predicted value 1, actual value bs
# 162) Predicted value 1, actual value bs
# 163) Predicted value 1, actual value bs
# 164) Predicted value 1, actual value bs
# 165) Predicted value 1, actual value bs
# 166) Predicted value 1, actual value bs
# 167) Predicted value 1, actual value bs
# 168) Predicted value 1, actual value bs
# 169) Predicted value 1, actual value bs
# 170) Predicted value 1, actual value bs
# 171) Predicted value 1, actual value bs
# 172) Predicted value 1, actual value bs
# 173) Predicted value 1, actual value bs
# 174) Predicted value 1, actual value bs
# 175) Predicted value 1, actual value bs
# 176) Predicted value 1, actual value bs
# 177) Predicted value 1, actual value bs
# 178) Predicted value 1, actual value bs
# 179) Predicted value 1, actual value bs
# 180) Predicted value 1, actual value bs
# 181) Predicted value 1, actual value bs
# 182) Predicted value 1, actual value bs
# 183) Predicted value 1, actual value bs
# 184) Predicted value 1, actual value bs
# 185) Predicted value 1, actual value bs
# 186) Predicted value 1, actual value bs
# 187) Predicted value 1, actual value bs
# 188) Predicted value 1, actual value bs
# 189) Predicted value 1, actual value bs
# 190) Predicted value 1, actual value bs
# 191) Predicted value 1, actual value bs
# 192) Predicted value 1, actual value bs
# 193) Predicted value 1, actual value bs
# 194) Predicted value 1, actual value bs
# 195) Predicted value 1, actual value bs
# 196) Predicted value 1, actual value bs
# 197) Predicted value 1, actual value bs
# 198) Predicted value 1, actual value bs
# 199) Predicted value 1, actual value bs
# 200) Predicted value 1, actual value bs
# 201) Predicted value 1, actual value bs
# 202) Predicted value 1, actual value bs
# 203) Predicted value 1, actual value bs
# 204) Predicted value 1, actual value bs
# 205) Predicted value 1, actual value bs
# 206) Predicted value 1, actual value bs
# 207) Predicted value 1, actual value bs
# 208) Predicted value 1, actual value bs
# 209) Predicted value 1, actual value bs
# 210) Predicted value 1, actual value bs
# 211) Predicted value 1, actual value bs
# 212) Predicted value 1, actual value bs
# 213) Predicted value 1, actual value bs
# 214) Predicted value 1, actual value bs
# 215) Predicted value 1, actual value bs
# 216) Predicted value 1, actual value bs
# 217) Predicted value 1, actual value bs
# 218) Predicted value 1, actual value bs
# 219) Predicted value 1, actual value bs
# 220) Predicted value 1, actual value bs
# 221) Predicted value 1, actual value bs
# 222) Predicted value 1, actual value bs
# 223) Predicted value 1, actual value bs
# 224) Predicted value 1, actual value bs
# 225) Predicted value 1, actual value bs
# 226) Predicted value 1, actual value bs
# 227) Predicted value 1, actual value bs
# 228) Predicted value 1, actual value bs
# 229) Predicted value 1, actual value bs
# 230) Predicted value 1, actual value bs
# 231) Predicted value 1, actual value bs
# 232) Predicted value 1, actual value bs
# 233) Predicted value 1, actual value bs
# 234) Predicted value 0, actual value bs
# 235) Predicted value 1, actual value bs
# 236) Predicted value 1, actual value bs
# 237) Predicted value 1, actual value bs
# 238) Predicted value 1, actual value bs
# 239) Predicted value 1, actual value bs
# 240) Predicted value 0, actual value bs
# 241) Predicted value 0, actual value bs
# 242) Predicted value 0, actual value bs
# 243) Predicted value 0, actual value bs
# 244) Predicted value 0, actual value bs
# 245) Predicted value 0, actual value bs
# 246) Predicted value 0, actual value bs
# 247) Predicted value 0, actual value bs
# 248) Predicted value 0, actual value bs
# 249) Predicted value 0, actual value bs
# 250) Predicted value 0, actual value bs
# 251) Predicted value 0, actual value bs
# 252) Predicted value 0, actual value bs
# 253) Predicted value 0, actual value bs
# 254) Predicted value 0, actual value bs
# 255) Predicted value 0, actual value bs
# 256) Predicted value 0, actual value bs
# 257) Predicted value 0, actual value bs
# 258) Predicted value 0, actual value bs
# 259) Predicted value 0, actual value conspiracy
# 260) Predicted value 0, actual value conspiracy
# 261) Predicted value 0, actual value conspiracy
# 262) Predicted value 0, actual value conspiracy
# 263) Predicted value 0, actual value conspiracy
# 264) Predicted value 0, actual value conspiracy
# 265) Predicted value 0, actual value conspiracy
# 266) Predicted value 0, actual value conspiracy
# 267) Predicted value 0, actual value conspiracy
# 268) Predicted value 0, actual value conspiracy
# 269) Predicted value 0, actual value conspiracy
# 270) Predicted value 0, actual value conspiracy
# 271) Predicted value 0, actual value conspiracy
# 272) Predicted value 0, actual value conspiracy
# 273) Predicted value 0, actual value conspiracy
# 274) Predicted value 0, actual value conspiracy
# 275) Predicted value 0, actual value conspiracy
# 276) Predicted value 0, actual value conspiracy
# 277) Predicted value 0, actual value conspiracy
# 278) Predicted value 0, actual value conspiracy
# 279) Predicted value 0, actual value conspiracy
# 280) Predicted value 0, actual value conspiracy
# 281) Predicted value 0, actual value conspiracy
# 282) Predicted value 0, actual value conspiracy
# 283) Predicted value 0, actual value conspiracy
# 284) Predicted value 0, actual value conspiracy
# 285) Predicted value 0, actual value conspiracy
# 286) Predicted value 0, actual value conspiracy
# 287) Predicted value 0, actual value conspiracy
# 288) Predicted value 0, actual value conspiracy
# 289) Predicted value 0, actual value conspiracy
# 290) Predicted value 0, actual value conspiracy
# 291) Predicted value 0, actual value conspiracy
# 292) Predicted value 0, actual value conspiracy
# 293) Predicted value 0, actual value conspiracy
# 294) Predicted value 0, actual value conspiracy
# 295) Predicted value 0, actual value conspiracy
# 296) Predicted value 0, actual value conspiracy
# 297) Predicted value 0, actual value conspiracy
# 298) Predicted value 0, actual value conspiracy
# 299) Predicted value 0, actual value conspiracy
# 300) Predicted value 0, actual value conspiracy
# 301) Predicted value 0, actual value conspiracy
# 302) Predicted value 0, actual value conspiracy
# 303) Predicted value 0, actual value conspiracy
# 304) Predicted value 0, actual value conspiracy
# 305) Predicted value 0, actual value conspiracy
# 306) Predicted value 0, actual value conspiracy
# 307) Predicted value 0, actual value conspiracy
# 308) Predicted value 0, actual value conspiracy
# 309) Predicted value 0, actual value conspiracy
# 310) Predicted value 0, actual value conspiracy
# 311) Predicted value 0, actual value conspiracy
# 312) Predicted value 0, actual value conspiracy
# 313) Predicted value 0, actual value conspiracy
# 314) Predicted value 0, actual value conspiracy
# 315) Predicted value 0, actual value conspiracy
# 316) Predicted value 0, actual value conspiracy
# 317) Predicted value 0, actual value conspiracy
# 318) Predicted value 0, actual value conspiracy
# 319) Predicted value 0, actual value conspiracy
# 320) Predicted value 0, actual value conspiracy
# 321) Predicted value 0, actual value conspiracy
# 322) Predicted value 0, actual value conspiracy
# 323) Predicted value 0, actual value conspiracy
# 324) Predicted value 0, actual value conspiracy
# 325) Predicted value 0, actual value conspiracy
# 326) Predicted value 0, actual value conspiracy
# 327) Predicted value 0, actual value conspiracy
# 328) Predicted value 0, actual value conspiracy
# 329) Predicted value 0, actual value conspiracy
# 330) Predicted value 0, actual value conspiracy
# 331) Predicted value 0, actual value conspiracy
# 332) Predicted value 0, actual value conspiracy
# 333) Predicted value 0, actual value conspiracy
# 334) Predicted value 0, actual value conspiracy
# 335) Predicted value 0, actual value conspiracy
# 336) Predicted value 0, actual value conspiracy
# 337) Predicted value 0, actual value conspiracy
# 338) Predicted value 0, actual value conspiracy
# 339) Predicted value 1, actual value conspiracy
# 340) Predicted value 1, actual value conspiracy
# 341) Predicted value 1, actual value conspiracy
# 342) Predicted value 1, actual value conspiracy
# 343) Predicted value 1, actual value conspiracy
# 344) Predicted value 1, actual value conspiracy
# 345) Predicted value 1, actual value conspiracy
# 346) Predicted value 1, actual value conspiracy
# 347) Predicted value 1, actual value conspiracy
# 348) Predicted value 1, actual value conspiracy
# 349) Predicted value 1, actual value conspiracy
# 350) Predicted value 1, actual value conspiracy
# 351) Predicted value 1, actual value conspiracy
# 352) Predicted value 1, actual value conspiracy
# 353) Predicted value 1, actual value conspiracy
# 354) Predicted value 1, actual value conspiracy
# 355) Predicted value 1, actual value conspiracy
# 356) Predicted value 1, actual value conspiracy
# 357) Predicted value 1, actual value conspiracy
# 358) Predicted value 1, actual value conspiracy
# 359) Predicted value 1, actual value bias
# 360) Predicted value 1, actual value bias
# 361) Predicted value 1, actual value bias
# 362) Predicted value 1, actual value bias
# 363) Predicted value 1, actual value bias
# 364) Predicted value 1, actual value bias
# 365) Predicted value 1, actual value bias
# 366) Predicted value 1, actual value bias
# 367) Predicted value 1, actual value bias
# 368) Predicted value 1, actual value bias
# 369) Predicted value 1, actual value bias
# 370) Predicted value 1, actual value bias
# 371) Predicted value 1, actual value bias
# 372) Predicted value 1, actual value bias
# 373) Predicted value 1, actual value bias
# 374) Predicted value 1, actual value bias
# 375) Predicted value 1, actual value bias
# 376) Predicted value 1, actual value bias
# 377) Predicted value 1, actual value bias
# 378) Predicted value 1, actual value bias
# 379) Predicted value 1, actual value fake
# 380) Predicted value 1, actual value fake
# 381) Predicted value 1, actual value fake
# 382) Predicted value 1, actual value fake
# 383) Predicted value 1, actual value fake
# 384) Predicted value 1, actual value fake
# 385) Predicted value 1, actual value fake
# 386) Predicted value 1, actual value fake
# 387) Predicted value 1, actual value fake
# 388) Predicted value 1, actual value fake
# 389) Predicted value 1, actual value fake
# 390) Predicted value 1, actual value fake
# 391) Predicted value 1, actual value fake
# 392) Predicted value 1, actual value bs
# 393) Predicted value 1, actual value bs
# 394) Predicted value 1, actual value bs
# 395) Predicted value 1, actual value bs
# 396) Predicted value 1, actual value bs
# 397) Predicted value 1, actual value bs
# 398) Predicted value 1, actual value bs
# 399) Predicted value 1, actual value bs
# 400) Predicted value 1, actual value bs
# 401) Predicted value 1, actual value bs
# 402) Predicted value 1, actual value bs
# 403) Predicted value 1, actual value bs
# 404) Predicted value 1, actual value bs
# 405) Predicted value 1, actual value bs
# 406) Predicted value 1, actual value bs
# 407) Predicted value 1, actual value bs
# 408) Predicted value 1, actual value bs
# 409) Predicted value 1, actual value bs
# 410) Predicted value 1, actual value bs
# 411) Predicted value 1, actual value bs
# 412) Predicted value 1, actual value bs
# 413) Predicted value 1, actual value bs
# 414) Predicted value 1, actual value bs
# 415) Predicted value 1, actual value bs
# 416) Predicted value 1, actual value bs
# 417) Predicted value 1, actual value bs
# 418) Predicted value 1, actual value bs
# 419) Predicted value 1, actual value bs
# 420) Predicted value 1, actual value bs
# 421) Predicted value 1, actual value bs
# 422) Predicted value 1, actual value bs
# 423) Predicted value 1, actual value bs
# 424) Predicted value 1, actual value bs
# 425) Predicted value 1, actual value bs
# 426) Predicted value 1, actual value bs
# 427) Predicted value 1, actual value bs
# 428) Predicted value 1, actual value bs
# 429) Predicted value 1, actual value bs
# 430) Predicted value 1, actual value bs
# 431) Predicted value 1, actual value bs
# 432) Predicted value 1, actual value bs
# 433) Predicted value 1, actual value bs
# 434) Predicted value 1, actual value bs
# 435) Predicted value 1, actual value bs
# 436) Predicted value 1, actual value bs
# 437) Predicted value 1, actual value bs
# 438) Predicted value 1, actual value bs
# 439) Predicted value 0, actual value bs
# 440) Predicted value 0, actual value bs
# 441) Predicted value 0, actual value bs
# 442) Predicted value 0, actual value bs
# 443) Predicted value 0, actual value bs
# 444) Predicted value 0, actual value bs
# 445) Predicted value 0, actual value bs
# 446) Predicted value 0, actual value bs
# 447) Predicted value 0, actual value bs
# 448) Predicted value 0, actual value bs
# 449) Predicted value 0, actual value bs
# 450) Predicted value 0, actual value bs
# 451) Predicted value 0, actual value bs
# 452) Predicted value 0, actual value bs
# 453) Predicted value 0, actual value bs
# 454) Predicted value 0, actual value bs
# 455) Predicted value 0, actual value bs
# 456) Predicted value 0, actual value bs
# 457) Predicted value 0, actual value bs
# 458) Predicted value 0, actual value bs
# 459) Predicted value 0, actual value bs
# 460) Predicted value 0, actual value bs
# 461) Predicted value 0, actual value bs
# 462) Predicted value 0, actual value bs
# 463) Predicted value 0, actual value bs
# 464) Predicted value 0, actual value bs
# 465) Predicted value 0, actual value bs
# 466) Predicted value 0, actual value bs
# 467) Predicted value 0, actual value bs
# 468) Predicted value 0, actual value bs
# 469) Predicted value 0, actual value bs
# 470) Predicted value 0, actual value bs
# 471) Predicted value 0, actual value bs
# 472) Predicted value 0, actual value bs
# 473) Predicted value 0, actual value bs
# 474) Predicted value 0, actual value bs
# 475) Predicted value 0, actual value bs
# 476) Predicted value 0, actual value bs
# 477) Predicted value 0, actual value bs
# 478) Predicted value 0, actual value bs
# 479) Predicted value 0, actual value bs
# 480) Predicted value 0, actual value bs
# 481) Predicted value 0, actual value bs
# 482) Predicted value 0, actual value bs
# 483) Predicted value 0, actual value bs
# 484) Predicted value 0, actual value bs
# 485) Predicted value 0, actual value bs
# 486) Predicted value 0, actual value bs
# 487) Predicted value 0, actual value bs
# 488) Predicted value 0, actual value bs
# 489) Predicted value 0, actual value bs
# 490) Predicted value 0, actual value bs
# 491) Predicted value 0, actual value bs
# 492) Predicted value 0, actual value bs
# 493) Predicted value 0, actual value bs
# 494) Predicted value 0, actual value bs
# 495) Predicted value 0, actual value bs
# 496) Predicted value 0, actual value bs
# 497) Predicted value 0, actual value bs
# 498) Predicted value 0, actual value bs
# 499) Predicted value 0, actual value bs
# 500) Predicted value 0, actual value bs
# 501) Predicted value 0, actual value bs
# 502) Predicted value 0, actual value bs
# 503) Predicted value 0, actual value bs
# 504) Predicted value 0, actual value bs
# 505) Predicted value 0, actual value bs
# 506) Predicted value 0, actual value bs
# 507) Predicted value 0, actual value bs
# 508) Predicted value 0, actual value bs
# 509) Predicted value 0, actual value bs
# 510) Predicted value 0, actual value bs
# 511) Predicted value 0, actual value bs
# 512) Predicted value 0, actual value bs
# 513) Predicted value 0, actual value bs
# 514) Predicted value 0, actual value bs
# 515) Predicted value 0, actual value bs
# 516) Predicted value 0, actual value bs
# 517) Predicted value 0, actual value bs
# 518) Predicted value 0, actual value bs
# 519) Predicted value 0, actual value bs
# 520) Predicted value 0, actual value bs
# 521) Predicted value 0, actual value bs
# 522) Predicted value 0, actual value bs
# 523) Predicted value 0, actual value bs
# 524) Predicted value 0, actual value bs
# 525) Predicted value 0, actual value bs
# 526) Predicted value 0, actual value bs
# 527) Predicted value 0, actual value bs
# 528) Predicted value 0, actual value bs
# 529) Predicted value 0, actual value bs
# 530) Predicted value 0, actual value bs
# 531) Predicted value 0, actual value bs
# 532) Predicted value 0, actual value bs
# 533) Predicted value 0, actual value bs
# 534) Predicted value 0, actual value bs
# 535) Predicted value 0, actual value bs
# 536) Predicted value 0, actual value bs
# 537) Predicted value 0, actual value bs
# 538) Predicted value 0, actual value bs
# 539) Predicted value 0, actual value bs
# 540) Predicted value 0, actual value bs
# 541) Predicted value 0, actual value bs
# 542) Predicted value 0, actual value bs
# 543) Predicted value 0, actual value bs
# 544) Predicted value 0, actual value bs
# 545) Predicted value 0, actual value bs
# 546) Predicted value 0, actual value bs
# 547) Predicted value 0, actual value bs
# 548) Predicted value 0, actual value bs
# 549) Predicted value 0, actual value bs
# 550) Predicted value 0, actual value bs
# 551) Predicted value 0, actual value bs
# 552) Predicted value 0, actual value bs
# 553) Predicted value 0, actual value bs
# 554) Predicted value 0, actual value bs
# 555) Predicted value 0, actual value bs
# 556) Predicted value 0, actual value bs
# 557) Predicted value 0, actual value bs
# 558) Predicted value 0, actual value bs
# 559) Predicted value 0, actual value bs
# 560) Predicted value 0, actual value bs
# 561) Predicted value 0, actual value bs
# 562) Predicted value 0, actual value bs
# 563) Predicted value 0, actual value bs
# 564) Predicted value 0, actual value bs
# 565) Predicted value 0, actual value bs
# 566) Predicted value 0, actual value bs
# 567) Predicted value 0, actual value bs
# 568) Predicted value 0, actual value bs
# 569) Predicted value 0, actual value bs
# 570) Predicted value 0, actual value bs
# 571) Predicted value 0, actual value bs
# 572) Predicted value 0, actual value bs
# 573) Predicted value 0, actual value bs
# 574) Predicted value 0, actual value bs
# 575) Predicted value 0, actual value bs
# 576) Predicted value 0, actual value bs
# 577) Predicted value 0, actual value bs
# 578) Predicted value 0, actual value bs
# 579) Predicted value 0, actual value bs
# 580) Predicted value 0, actual value bs
# 581) Predicted value 0, actual value bs
# 582) Predicted value 0, actual value bs
# 583) Predicted value 0, actual value bs
# 584) Predicted value 0, actual value bs
# 585) Predicted value 0, actual value bs
# 586) Predicted value 0, actual value bs
# 587) Predicted value 0, actual value bs
# 588) Predicted value 0, actual value bs
# 589) Predicted value 0, actual value bs
# 590) Predicted value 0, actual value bs
# 591) Predicted value 0, actual value bs
# 592) Predicted value 0, actual value bs
# 593) Predicted value 0, actual value bs
# 594) Predicted value 0, actual value bs
# 595) Predicted value 0, actual value bs
# 596) Predicted value 0, actual value bs
# 597) Predicted value 0, actual value bs
# 598) Predicted value 0, actual value bs
# 599) Predicted value 0, actual value bs
# 600) Predicted value 0, actual value bs
# 601) Predicted value 0, actual value bs
# 602) Predicted value 0, actual value bs
# 603) Predicted value 0, actual value bs
# 604) Predicted value 0, actual value bs
# 605) Predicted value 0, actual value bs
# 606) Predicted value 0, actual value bs
# 607) Predicted value 0, actual value bs
# 608) Predicted value 0, actual value bs
# 609) Predicted value 0, actual value bs
# 610) Predicted value 0, actual value bs
# 611) Predicted value 0, actual value bs
# 612) Predicted value 0, actual value bs
# 613) Predicted value 0, actual value bs
# 614) Predicted value 0, actual value bs
# 615) Predicted value 0, actual value bs
# 616) Predicted value 0, actual value bs
# 617) Predicted value 0, actual value bs
# 618) Predicted value 0, actual value bs
# 619) Predicted value 0, actual value bs
# 620) Predicted value 0, actual value bs
# 621) Predicted value 0, actual value bs
# 622) Predicted value 0, actual value bs
# 623) Predicted value 0, actual value bs
# 624) Predicted value 0, actual value bs
# 625) Predicted value 0, actual value bs
# 626) Predicted value 0, actual value bs
# 627) Predicted value 0, actual value bs
# 628) Predicted value 0, actual value bs
# 629) Predicted value 0, actual value bs
# 630) Predicted value 0, actual value bs
# 631) Predicted value 0, actual value bs
# 632) Predicted value 0, actual value bs
# 633) Predicted value 0, actual value bs
# 634) Predicted value 0, actual value bs
# 635) Predicted value 0, actual value bs
# 636) Predicted value 0, actual value bs
# 637) Predicted value 0, actual value bs
# 638) Predicted value 1, actual value bs
# 639) Predicted value 1, actual value bs
# 640) Predicted value 1, actual value bs
# 641) Predicted value 1, actual value bs
# 642) Predicted value 1, actual value bs
# 643) Predicted value 1, actual value bs
# 644) Predicted value 1, actual value bs
# 645) Predicted value 1, actual value bs
# 646) Predicted value 1, actual value bs
# 647) Predicted value 1, actual value bs
# 648) Predicted value 1, actual value bs
# 649) Predicted value 1, actual value bs
# 650) Predicted value 1, actual value bs
# 651) Predicted value 1, actual value bs
# 652) Predicted value 1, actual value bs
# 653) Predicted value 1, actual value bs
# 654) Predicted value 1, actual value bs
# 655) Predicted value 1, actual value bs
# 656) Predicted value 1, actual value bs
# 657) Predicted value 1, actual value bs
# 658) Predicted value 1, actual value bs
# 659) Predicted value 1, actual value bs
# 660) Predicted value 1, actual value bs
# 661) Predicted value 1, actual value bs
# 662) Predicted value 1, actual value bs
# 663) Predicted value 1, actual value bs
# 664) Predicted value 1, actual value bs
# 665) Predicted value 1, actual value bs
# 666) Predicted value 1, actual value bs
# 667) Predicted value 1, actual value bs
# 668) Predicted value 1, actual value bs
# 669) Predicted value 1, actual value bs
# 670) Predicted value 1, actual value bs
# 671) Predicted value 1, actual value bs
# 672) Predicted value 1, actual value bs
# 673) Predicted value 1, actual value bs
# 674) Predicted value 1, actual value bs
# 675) Predicted value 1, actual value bs
# 676) Predicted value 1, actual value bs
# 677) Predicted value 1, actual value bs
# 678) Predicted value 1, actual value bs
# 679) Predicted value 1, actual value bs
# 680) Predicted value 1, actual value bs
# 681) Predicted value 1, actual value bs
# 682) Predicted value 1, actual value bs
# 683) Predicted value 1, actual value bs
# 684) Predicted value 1, actual value bs
# 685) Predicted value 1, actual value bs
# 686) Predicted value 1, actual value bs
# 687) Predicted value 1, actual value bs
# 688) Predicted value 1, actual value bs
# 689) Predicted value 1, actual value bs
# 690) Predicted value 1, actual value bs
# 691) Predicted value 1, actual value bs
# 692) Predicted value 1, actual value bs
# 693) Predicted value 1, actual value bs
# 694) Predicted value 1, actual value bs
# 695) Predicted value 1, actual value bs
# 696) Predicted value 1, actual value bs
# 697) Predicted value 1, actual value bs
# 698) Predicted value 1, actual value bs
# 699) Predicted value 1, actual value bs
# 700) Predicted value 1, actual value bs
# 701) Predicted value 1, actual value bs
# 702) Predicted value 1, actual value bs
# 703) Predicted value 1, actual value bs
# 704) Predicted value 1, actual value bs
# 705) Predicted value 1, actual value bs
# 706) Predicted value 1, actual value bs
# 707) Predicted value 1, actual value bs
# 708) Predicted value 1, actual value bs
# 709) Predicted value 1, actual value bs
# 710) Predicted value 1, actual value bs
# 711) Predicted value 1, actual value bs
# 712) Predicted value 1, actual value bs
# 713) Predicted value 1, actual value bs
# 714) Predicted value 1, actual value bs
# 715) Predicted value 1, actual value bs
# 716) Predicted value 1, actual value bs
# 717) Predicted value 1, actual value bs
# 718) Predicted value 1, actual value bs
# 719) Predicted value 1, actual value bs
# 720) Predicted value 1, actual value bs
# 721) Predicted value 1, actual value bs
# 722) Predicted value 1, actual value bs
# 723) Predicted value 1, actual value bs
# 724) Predicted value 1, actual value bs
# 725) Predicted value 1, actual value bs
# 726) Predicted value 1, actual value bs
# 727) Predicted value 1, actual value bs
# 728) Predicted value 1, actual value bs
# 729) Predicted value 1, actual value bs
# 730) Predicted value 1, actual value bs
# 731) Predicted value 1, actual value bs
# 732) Predicted value 1, actual value bs
# 733) Predicted value 1, actual value bs
# 734) Predicted value 1, actual value bs
# 735) Predicted value 1, actual value bs
# 736) Predicted value 1, actual value bs
# 737) Predicted value 1, actual value bs
# 738) Predicted value 1, actual value bs
# 739) Predicted value 1, actual value bs
# 740) Predicted value 1, actual value bs
# 741) Predicted value 1, actual value bs
# 742) Predicted value 1, actual value bs
# 743) Predicted value 1, actual value bs
# 744) Predicted value 1, actual value bs
# 745) Predicted value 0, actual value bs
# 746) Predicted value 1, actual value bs
# 747) Predicted value 1, actual value bs
# 748) Predicted value 1, actual value bs
# 749) Predicted value 1, actual value bs
# 750) Predicted value 1, actual value bs
# 751) Predicted value 1, actual value bs
# 752) Predicted value 1, actual value bs
# 753) Predicted value 1, actual value bs
# 754) Predicted value 1, actual value bs
# 755) Predicted value 1, actual value bs
# 756) Predicted value 1, actual value bs
# 757) Predicted value 1, actual value bs
# 758) Predicted value 1, actual value bs
# 759) Predicted value 1, actual value bs
# 760) Predicted value 1, actual value bs
# 761) Predicted value 1, actual value bs
# 762) Predicted value 1, actual value bs
# 763) Predicted value 1, actual value bs
# 764) Predicted value 1, actual value bs
# 765) Predicted value 1, actual value bs
# 766) Predicted value 1, actual value bs
# 767) Predicted value 1, actual value bs
# 768) Predicted value 1, actual value bs
# 769) Predicted value 1, actual value bs
# 770) Predicted value 1, actual value bs
# 771) Predicted value 1, actual value bs
# 772) Predicted value 1, actual value bs
# 773) Predicted value 1, actual value bs
# 774) Predicted value 1, actual value bs
# 775) Predicted value 1, actual value bs
# 776) Predicted value 1, actual value bs
# 777) Predicted value 1, actual value bs
# 778) Predicted value 1, actual value bs
# 779) Predicted value 1, actual value bs
# 780) Predicted value 1, actual value bs
# 781) Predicted value 1, actual value bs
# 782) Predicted value 1, actual value bs
# 783) Predicted value 1, actual value bs
# 784) Predicted value 1, actual value bs
# 785) Predicted value 1, actual value bs
# 786) Predicted value 1, actual value bs
# 787) Predicted value 1, actual value bs
# 788) Predicted value 1, actual value bs
# 789) Predicted value 1, actual value bs
# 790) Predicted value 1, actual value bs
# 791) Predicted value 1, actual value bs
# 792) Predicted value 1, actual value bs
# 793) Predicted value 1, actual value bs
# 794) Predicted value 1, actual value bs
# 795) Predicted value 1, actual value bs
# 796) Predicted value 1, actual value bs
# 797) Predicted value 1, actual value bs
# 798) Predicted value 1, actual value bs
# 799) Predicted value 1, actual value bs
# 800) Predicted value 1, actual value bs
# 801) Predicted value 1, actual value bs
# 802) Predicted value 1, actual value bs
# 803) Predicted value 1, actual value bs
# 804) Predicted value 1, actual value bs
# 805) Predicted value 1, actual value bs
# 806) Predicted value 1, actual value bs
# 807) Predicted value 1, actual value bs
# 808) Predicted value 1, actual value bs
# 809) Predicted value 1, actual value bs
# 810) Predicted value 1, actual value bs
# 811) Predicted value 1, actual value bs
# 812) Predicted value 1, actual value bs
# 813) Predicted value 1, actual value bs
# 814) Predicted value 1, actual value bs
# 815) Predicted value 1, actual value bs
# 816) Predicted value 1, actual value bs
# 817) Predicted value 1, actual value bs
# 818) Predicted value 1, actual value bs
# 819) Predicted value 1, actual value bs
# 820) Predicted value 1, actual value bs
# 821) Predicted value 1, actual value bs
# 822) Predicted value 1, actual value bs
# 823) Predicted value 1, actual value bs
# 824) Predicted value 1, actual value bs
# 825) Predicted value 1, actual value bs
# 826) Predicted value 1, actual value bs
# 827) Predicted value 1, actual value bs
# 828) Predicted value 1, actual value bs
# 829) Predicted value 1, actual value bs
# 830) Predicted value 1, actual value bs
# 831) Predicted value 1, actual value bs
# 832) Predicted value 1, actual value bs
# 833) Predicted value 1, actual value bs
# 834) Predicted value 1, actual value bs
# 835) Predicted value 1, actual value bs
# 836) Predicted value 1, actual value bs
# 837) Predicted value 1, actual value bs
# 838) Predicted value 1, actual value bs
# 839) Predicted value 1, actual value bs
# 840) Predicted value 1, actual value bs
# 841) Predicted value 1, actual value bs
# 842) Predicted value 1, actual value bs
# 843) Predicted value 1, actual value bs
# 844) Predicted value 1, actual value bs
# 845) Predicted value 1, actual value bs
# 846) Predicted value 1, actual value bs
# 847) Predicted value 1, actual value bs
# 848) Predicted value 1, actual value bs
# 849) Predicted value 1, actual value bs
# 850) Predicted value 1, actual value bs
# 851) Predicted value 1, actual value bs
# 852) Predicted value 1, actual value bs
# 853) Predicted value 1, actual value bs
# 854) Predicted value 1, actual value bs
# 855) Predicted value 1, actual value bs
# 856) Predicted value 1, actual value bs
# 857) Predicted value 1, actual value bs
# 858) Predicted value 1, actual value bs
# 859) Predicted value 1, actual value bs
# 860) Predicted value 1, actual value bs
# 861) Predicted value 1, actual value bs
# 862) Predicted value 1, actual value bs
# 863) Predicted value 1, actual value bs
# 864) Predicted value 1, actual value bs
# 865) Predicted value 1, actual value bs
# 866) Predicted value 1, actual value bs
# 867) Predicted value 1, actual value bs
# 868) Predicted value 1, actual value bs
# 869) Predicted value 1, actual value bs
# 870) Predicted value 1, actual value bs
# 871) Predicted value 1, actual value bs
# 872) Predicted value 1, actual value bs
# 873) Predicted value 1, actual value bs
# 874) Predicted value 1, actual value bs
# 875) Predicted value 1, actual value bs
# 876) Predicted value 1, actual value bs
# 877) Predicted value 1, actual value bs
# 878) Predicted value 1, actual value bs
# 879) Predicted value 1, actual value bs
# 880) Predicted value 1, actual value bs
# 881) Predicted value 1, actual value bs
# 882) Predicted value 1, actual value bs
# 883) Predicted value 1, actual value bs
# 884) Predicted value 1, actual value bs
# 885) Predicted value 1, actual value bs
# 886) Predicted value 1, actual value bs
# 887) Predicted value 1, actual value bs
# 888) Predicted value 1, actual value bs
# 889) Predicted value 1, actual value bs
# 890) Predicted value 1, actual value bs
# 891) Predicted value 1, actual value bs
# 892) Predicted value 1, actual value bs
# 893) Predicted value 1, actual value bs
# 894) Predicted value 1, actual value bs
# 895) Predicted value 1, actual value bs
# 896) Predicted value 1, actual value bs
# 897) Predicted value 1, actual value bs
# 898) Predicted value 1, actual value bs
# 899) Predicted value 1, actual value bs
# 900) Predicted value 1, actual value bs
# 901) Predicted value 1, actual value bs
# 902) Predicted value 1, actual value bs
# 903) Predicted value 1, actual value bs
# 904) Predicted value 1, actual value bs
# 905) Predicted value 1, actual value bs
# 906) Predicted value 1, actual value bs
# 907) Predicted value 1, actual value bs
# 908) Predicted value 1, actual value bs
# 909) Predicted value 1, actual value bs
# 910) Predicted value 1, actual value conspiracy
# 911) Predicted value 1, actual value conspiracy
# 912) Predicted value 1, actual value conspiracy
# 913) Predicted value 1, actual value conspiracy
# 914) Predicted value 1, actual value conspiracy
# 915) Predicted value 1, actual value conspiracy
# 916) Predicted value 1, actual value conspiracy
# 917) Predicted value 1, actual value conspiracy
# 918) Predicted value 1, actual value conspiracy
# 919) Predicted value 1, actual value conspiracy
# 920) Predicted value 1, actual value conspiracy
# 921) Predicted value 1, actual value conspiracy
# 922) Predicted value 1, actual value conspiracy
# 923) Predicted value 1, actual value conspiracy
# 924) Predicted value 1, actual value conspiracy
# 925) Predicted value 1, actual value conspiracy
# 926) Predicted value 1, actual value conspiracy
# 927) Predicted value 1, actual value conspiracy
# 928) Predicted value 1, actual value conspiracy
# 929) Predicted value 1, actual value conspiracy
# 930) Predicted value 1, actual value conspiracy
# 931) Predicted value 1, actual value conspiracy
# 932) Predicted value 1, actual value conspiracy
# 933) Predicted value 1, actual value conspiracy
# 934) Predicted value 1, actual value conspiracy
# 935) Predicted value 1, actual value conspiracy
# 936) Predicted value 1, actual value conspiracy
# 937) Predicted value 1, actual value conspiracy
# 938) Predicted value 1, actual value conspiracy
# 939) Predicted value 1, actual value conspiracy
# 940) Predicted value 1, actual value conspiracy
# 941) Predicted value 1, actual value conspiracy
# 942) Predicted value 1, actual value conspiracy
# 943) Predicted value 1, actual value conspiracy
# 944) Predicted value 1, actual value conspiracy
# 945) Predicted value 1, actual value conspiracy
# 946) Predicted value 1, actual value conspiracy
# 947) Predicted value 1, actual value conspiracy
# 948) Predicted value 1, actual value conspiracy
# 949) Predicted value 1, actual value conspiracy
# 950) Predicted value 1, actual value conspiracy
# 951) Predicted value 1, actual value conspiracy
# 952) Predicted value 1, actual value conspiracy
# 953) Predicted value 1, actual value conspiracy
# 954) Predicted value 1, actual value conspiracy
# 955) Predicted value 1, actual value conspiracy
# 956) Predicted value 1, actual value conspiracy
# 957) Predicted value 1, actual value conspiracy
# 958) Predicted value 1, actual value conspiracy
# 959) Predicted value 1, actual value conspiracy
# 960) Predicted value 1, actual value conspiracy
# 961) Predicted value 1, actual value conspiracy
# 962) Predicted value 1, actual value conspiracy
# 963) Predicted value 1, actual value conspiracy
# 964) Predicted value 1, actual value conspiracy
# 965) Predicted value 1, actual value conspiracy
# 966) Predicted value 1, actual value conspiracy
# 967) Predicted value 1, actual value conspiracy
# 968) Predicted value 1, actual value conspiracy
# 969) Predicted value 1, actual value conspiracy
# 970) Predicted value 1, actual value conspiracy
# 971) Predicted value 1, actual value conspiracy
# 972) Predicted value 1, actual value conspiracy
# 973) Predicted value 1, actual value conspiracy
# 974) Predicted value 1, actual value conspiracy
# 975) Predicted value 1, actual value conspiracy
# 976) Predicted value 1, actual value conspiracy
# 977) Predicted value 1, actual value conspiracy
# 978) Predicted value 1, actual value conspiracy
# 979) Predicted value 1, actual value conspiracy
# 980) Predicted value 1, actual value conspiracy
# 981) Predicted value 1, actual value conspiracy
# 982) Predicted value 1, actual value conspiracy
# 983) Predicted value 1, actual value conspiracy
# 984) Predicted value 1, actual value conspiracy
# 985) Predicted value 1, actual value conspiracy
# 986) Predicted value 1, actual value conspiracy
# 987) Predicted value 1, actual value conspiracy
# 988) Predicted value 1, actual value conspiracy
# 989) Predicted value 1, actual value conspiracy
# 990) Predicted value 1, actual value conspiracy
# 991) Predicted value 1, actual value conspiracy
# 992) Predicted value 1, actual value conspiracy
# 993) Predicted value 1, actual value conspiracy
# 994) Predicted value 1, actual value conspiracy
# 995) Predicted value 1, actual value conspiracy
# 996) Predicted value 1, actual value conspiracy
# 997) Predicted value 1, actual value conspiracy
# 998) Predicted value 1, actual value conspiracy
# 999) Predicted value 1, actual value conspiracy
# 1000) Predicted value 1, actual value conspiracy
# 1001) Predicted value 1, actual value conspiracy
# 1002) Predicted value 1, actual value conspiracy
# 1003) Predicted value 1, actual value conspiracy
# 1004) Predicted value 1, actual value conspiracy
# 1005) Predicted value 1, actual value conspiracy
# 1006) Predicted value 1, actual value conspiracy
# 1007) Predicted value 1, actual value conspiracy
# 1008) Predicted value 1, actual value conspiracy
# 1009) Predicted value 1, actual value conspiracy
# 1010) Predicted value 1, actual value bs
# 1011) Predicted value 1, actual value bs
# 1012) Predicted value 1, actual value bs
# 1013) Predicted value 1, actual value bs
# 1014) Predicted value 1, actual value bs
# 1015) Predicted value 1, actual value bs
# 1016) Predicted value 1, actual value bs
# 1017) Predicted value 1, actual value bs
# 1018) Predicted value 1, actual value bs
# 1019) Predicted value 1, actual value bs
# 1020) Predicted value 1, actual value bs
# 1021) Predicted value 1, actual value bs
# 1022) Predicted value 1, actual value bs
# 1023) Predicted value 1, actual value bs
# 1024) Predicted value 1, actual value bs
# 1025) Predicted value 1, actual value bs
# 1026) Predicted value 1, actual value bs
# 1027) Predicted value 1, actual value bs
# 1028) Predicted value 1, actual value bs
# 1029) Predicted value 1, actual value bs
# 1030) Predicted value 1, actual value bs
# 1031) Predicted value 1, actual value bs
# 1032) Predicted value 1, actual value bs
# 1033) Predicted value 1, actual value bs
# 1034) Predicted value 1, actual value bs
# 1035) Predicted value 1, actual value bs
# 1036) Predicted value 1, actual value bs
# 1037) Predicted value 1, actual value bs
# 1038) Predicted value 1, actual value bs
# 1039) Predicted value 1, actual value bs
# 1040) Predicted value 1, actual value bs
# 1041) Predicted value 1, actual value bs
# 1042) Predicted value 1, actual value bs
# 1043) Predicted value 1, actual value bs
# 1044) Predicted value 1, actual value bs
# 1045) Predicted value 1, actual value bs
# 1046) Predicted value 1, actual value bs
# 1047) Predicted value 1, actual value bs
# 1048) Predicted value 1, actual value bs
# 1049) Predicted value 1, actual value bs
# 1050) Predicted value 1, actual value bs
# 1051) Predicted value 1, actual value bs
# 1052) Predicted value 1, actual value bs
# 1053) Predicted value 1, actual value bs
# 1054) Predicted value 1, actual value bs
# 1055) Predicted value 1, actual value bs
# 1056) Predicted value 1, actual value bs
# 1057) Predicted value 1, actual value bs
# 1058) Predicted value 1, actual value bs
# 1059) Predicted value 1, actual value bs
# 1060) Predicted value 1, actual value bs
# 1061) Predicted value 1, actual value bs
# 1062) Predicted value 1, actual value bs
# 1063) Predicted value 1, actual value bs
# 1064) Predicted value 1, actual value bs
# 1065) Predicted value 1, actual value bs
# 1066) Predicted value 1, actual value bs
# 1067) Predicted value 1, actual value bs
# 1068) Predicted value 1, actual value bs
# 1069) Predicted value 1, actual value bs
# 1070) Predicted value 1, actual value bs
# 1071) Predicted value 1, actual value bs
# 1072) Predicted value 1, actual value bs
# 1073) Predicted value 1, actual value bs
# 1074) Predicted value 1, actual value bs
# 1075) Predicted value 1, actual value bs
# 1076) Predicted value 1, actual value bs
# 1077) Predicted value 1, actual value bs
# 1078) Predicted value 1, actual value bs
# 1079) Predicted value 1, actual value bs
# 1080) Predicted value 1, actual value bs
# 1081) Predicted value 1, actual value bs
# 1082) Predicted value 1, actual value bs
# 1083) Predicted value 1, actual value bs
# 1084) Predicted value 1, actual value bs
# 1085) Predicted value 1, actual value bs
# 1086) Predicted value 1, actual value bs
# 1087) Predicted value 1, actual value bs
# 1088) Predicted value 1, actual value bs
# 1089) Predicted value 1, actual value bs
# 1090) Predicted value 1, actual value bs
# 1091) Predicted value 1, actual value bs
# 1092) Predicted value 1, actual value bs
# 1093) Predicted value 1, actual value bs
# 1094) Predicted value 1, actual value bs
# 1095) Predicted value 1, actual value bs
# 1096) Predicted value 1, actual value bs
# 1097) Predicted value 1, actual value bs
# 1098) Predicted value 1, actual value bs
# 1099) Predicted value 1, actual value bs
# 1100) Predicted value 1, actual value bs
# 1101) Predicted value 1, actual value bs
# 1102) Predicted value 1, actual value bs
# 1103) Predicted value 1, actual value bs
# 1104) Predicted value 1, actual value bs
# 1105) Predicted value 1, actual value bs
# 1106) Predicted value 1, actual value bs
# 1107) Predicted value 1, actual value bs
# 1108) Predicted value 1, actual value bs
# 1109) Predicted value 1, actual value bs
# 1110) Predicted value 1, actual value bs
# 1111) Predicted value 1, actual value bs
# 1112) Predicted value 1, actual value bs
# 1113) Predicted value 1, actual value bs
# 1114) Predicted value 1, actual value bs
# 1115) Predicted value 1, actual value bs
# 1116) Predicted value 1, actual value bs
# 1117) Predicted value 1, actual value bs
# 1118) Predicted value 1, actual value bs
# 1119) Predicted value 1, actual value bs
# 1120) Predicted value 1, actual value bs
# 1121) Predicted value 1, actual value bs
# 1122) Predicted value 1, actual value bs
# 1123) Predicted value 1, actual value bs
# 1124) Predicted value 1, actual value bs
# 1125) Predicted value 1, actual value bs
# 1126) Predicted value 1, actual value bs
# 1127) Predicted value 1, actual value bs
# 1128) Predicted value 1, actual value bs
# 1129) Predicted value 1, actual value bs
# 1130) Predicted value 1, actual value bs
# 1131) Predicted value 1, actual value bs
# 1132) Predicted value 1, actual value bs
# 1133) Predicted value 1, actual value bs
# 1134) Predicted value 1, actual value bs
# 1135) Predicted value 1, actual value bs
# 1136) Predicted value 1, actual value bs
# 1137) Predicted value 1, actual value bs
# 1138) Predicted value 1, actual value bs
# 1139) Predicted value 1, actual value bs
# 1140) Predicted value 1, actual value bs
# 1141) Predicted value 1, actual value bs
# 1142) Predicted value 1, actual value bs
# 1143) Predicted value 1, actual value bs
# 1144) Predicted value 1, actual value bs
# 1145) Predicted value 1, actual value bs
# 1146) Predicted value 1, actual value bs
# 1147) Predicted value 1, actual value bs
# 1148) Predicted value 1, actual value bs
# 1149) Predicted value 1, actual value bs
# ...
# 6441) Predicted value 1, actual value junksci
# 6442) Predicted value 1, actual value junksci
# 6443) Predicted value 1, actual value junksci
# 6444) Predicted value 1, actual value junksci
# 6445) Predicted value 1, actual value junksci
# 6446) Predicted value 1, actual value junksci
# 6447) Predicted value 1, actual value junksci
# 6448) Predicted value 1, actual value junksci
# 6449) Predicted value 1, actual value junksci
# 6450) Predicted value 1, actual value junksci
# 6451) Predicted value 1, actual value junksci
# 6452) Predicted value 1, actual value junksci
# 6453) Predicted value 1, actual value junksci
# 6454) Predicted value 1, actual value junksci
# 6455) Predicted value 1, actual value junksci
# 6456) Predicted value 1, actual value junksci
# 6457) Predicted value 1, actual value junksci
# 6458) Predicted value 1, actual value junksci
# 6459) Predicted value 1, actual value junksci
# 6460) Predicted value 1, actual value junksci
# 6461) Predicted value 1, actual value junksci
# 6462) Predicted value 1, actual value junksci
# 6463) Predicted value 1, actual value junksci
# 6464) Predicted value 1, actual value junksci
# 6465) Predicted value 1, actual value junksci
# 6466) Predicted value 1, actual value junksci
# 6467) Predicted value 1, actual value junksci
# 6468) Predicted value 1, actual value junksci
# 6469) Predicted value 1, actual value junksci
# 6470) Predicted value 1, actual value junksci
# 6471) Predicted value 1, actual value junksci
# 6472) Predicted value 1, actual value junksci
# 6473) Predicted value 1, actual value junksci
# 6474) Predicted value 1, actual value junksci
# 6475) Predicted value 1, actual value junksci
# 6476) Predicted value 1, actual value junksci
# 6477) Predicted value 1, actual value junksci
# 6478) Predicted value 1, actual value junksci
# 6479) Predicted value 1, actual value junksci
# 6480) Predicted value 1, actual value junksci
# 6481) Predicted value 1, actual value junksci
# 6482) Predicted value 1, actual value junksci
# 6483) Predicted value 1, actual value junksci
# 6484) Predicted value 1, actual value junksci
# 6485) Predicted value 1, actual value junksci
# 6486) Predicted value 1, actual value junksci
# 6487) Predicted value 1, actual value junksci
# 6488) Predicted value 1, actual value junksci
# 6489) Predicted value 1, actual value junksci
# 6490) Predicted value 1, actual value junksci
# 6491) Predicted value 1, actual value junksci
# 6492) Predicted value 1, actual value junksci
# 6493) Predicted value 1, actual value junksci
# 6494) Predicted value 1, actual value junksci
# 6495) Predicted value 1, actual value junksci
# 6496) Predicted value 1, actual value junksci
# 6497) Predicted value 1, actual value junksci
# 6498) Predicted value 1, actual value junksci
# 6499) Predicted value 1, actual value junksci
# 6500) Predicted value 1, actual value junksci
# 6501) Predicted value 1, actual value junksci
# 6502) Predicted value 1, actual value junksci
# 6503) Predicted value 1, actual value junksci
# 6504) Predicted value 1, actual value junksci
# 6505) Predicted value 1, actual value junksci
# 6506) Predicted value 1, actual value junksci
# 6507) Predicted value 1, actual value junksci
# 6508) Predicted value 1, actual value junksci
# 6509) Predicted value 1, actual value junksci
# 6510) Predicted value 1, actual value junksci
# 6511) Predicted value 1, actual value junksci
# 6512) Predicted value 1, actual value junksci
# 6513) Predicted value 1, actual value junksci
# 6514) Predicted value 1, actual value junksci
# 6515) Predicted value 1, actual value junksci
# 6516) Predicted value 1, actual value junksci
# 6517) Predicted value 1, actual value junksci
# 6518) Predicted value 1, actual value junksci
# 6519) Predicted value 1, actual value junksci
# 6520) Predicted value 1, actual value junksci
# 6521) Predicted value 1, actual value junksci
# 6522) Predicted value 1, actual value bs
# 6523) Predicted value 1, actual value bs
# 6524) Predicted value 1, actual value bs
# 6525) Predicted value 1, actual value bs
# 6526) Predicted value 1, actual value bs
# 6527) Predicted value 1, actual value bs
# 6528) Predicted value 1, actual value bs
# 6529) Predicted value 1, actual value bs
# 6530) Predicted value 1, actual value bs
# 6531) Predicted value 1, actual value bs
# 6532) Predicted value 1, actual value bs
# 6533) Predicted value 1, actual value bs
# 6534) Predicted value 1, actual value bs
# 6535) Predicted value 1, actual value bs
# 6536) Predicted value 1, actual value bs
# 6537) Predicted value 1, actual value bs
# 6538) Predicted value 1, actual value bs
# 6539) Predicted value 1, actual value bs
# 6540) Predicted value 1, actual value bs
# 6541) Predicted value 1, actual value bs
# 6542) Predicted value 1, actual value bs
# 6543) Predicted value 1, actual value bs
# 6544) Predicted value 1, actual value bs
# 6545) Predicted value 1, actual value bs
# 6546) Predicted value 1, actual value bs
# 6547) Predicted value 1, actual value bs
# 6548) Predicted value 1, actual value bs
# 6549) Predicted value 1, actual value bs
# 6550) Predicted value 1, actual value bs
# 6551) Predicted value 1, actual value bs
# 6552) Predicted value 1, actual value bs
# 6553) Predicted value 1, actual value bs
# 6554) Predicted value 1, actual value bs
# 6555) Predicted value 1, actual value bs
# 6556) Predicted value 1, actual value bs
# 6557) Predicted value 1, actual value bs
# 6558) Predicted value 1, actual value bs
# 6559) Predicted value 1, actual value bs
# 6560) Predicted value 1, actual value bs
# 6561) Predicted value 1, actual value bs
# 6562) Predicted value 1, actual value bs
# 6563) Predicted value 1, actual value bs
# 6564) Predicted value 1, actual value bs
# 6565) Predicted value 1, actual value bs
# 6566) Predicted value 1, actual value bs
# 6567) Predicted value 1, actual value bs
# 6568) Predicted value 1, actual value bs
# 6569) Predicted value 1, actual value bs
# 6570) Predicted value 1, actual value bs
# 6571) Predicted value 1, actual value bs
# 6572) Predicted value 1, actual value bs
# 6573) Predicted value 1, actual value bs
# 6574) Predicted value 1, actual value bs
# 6575) Predicted value 1, actual value bs
# 6576) Predicted value 1, actual value bs
# 6577) Predicted value 1, actual value bs
# 6578) Predicted value 1, actual value bs
# 6579) Predicted value 1, actual value bs
# 6580) Predicted value 1, actual value bs
# 6581) Predicted value 1, actual value bs
# 6582) Predicted value 1, actual value bs
# 6583) Predicted value 1, actual value bs
# 6584) Predicted value 1, actual value bs
# 6585) Predicted value 1, actual value bs
# 6586) Predicted value 1, actual value bs
# 6587) Predicted value 1, actual value bs
# 6588) Predicted value 1, actual value bs
# 6589) Predicted value 1, actual value bs
# 6590) Predicted value 1, actual value bs
# 6591) Predicted value 1, actual value bs
# 6592) Predicted value 1, actual value bs
# 6593) Predicted value 1, actual value bs
# 6594) Predicted value 1, actual value bs
# 6595) Predicted value 1, actual value bs
# 6596) Predicted value 1, actual value bs
# 6597) Predicted value 1, actual value bs
# 6598) Predicted value 1, actual value bs
# 6599) Predicted value 1, actual value bs
# 6600) Predicted value 1, actual value bs
# 6601) Predicted value 1, actual value bs
# 6602) Predicted value 1, actual value bs
# 6603) Predicted value 1, actual value bs
# 6604) Predicted value 1, actual value bs
# 6605) Predicted value 1, actual value bs
# 6606) Predicted value 1, actual value bs
# 6607) Predicted value 1, actual value bs
# 6608) Predicted value 1, actual value bs
# 6609) Predicted value 1, actual value bs
# 6610) Predicted value 1, actual value bs
# 6611) Predicted value 1, actual value bs
# 6612) Predicted value 1, actual value bs
# 6613) Predicted value 1, actual value bs
# 6614) Predicted value 1, actual value bs
# 6615) Predicted value 1, actual value bs
# 6616) Predicted value 1, actual value bs
# 6617) Predicted value 1, actual value bs
# 6618) Predicted value 1, actual value bs
# 6619) Predicted value 0, actual value bs
# 6620) Predicted value 0, actual value bs
# 6621) Predicted value 0, actual value bs
# 6622) Predicted value 0, actual value bs
# 6623) Predicted value 0, actual value bs
# 6624) Predicted value 0, actual value bs
# 6625) Predicted value 0, actual value bs
# 6626) Predicted value 0, actual value bs
# 6627) Predicted value 0, actual value bs
# 6628) Predicted value 0, actual value bs
# 6629) Predicted value 0, actual value bs
# 6630) Predicted value 0, actual value bs
# 6631) Predicted value 0, actual value bs
# 6632) Predicted value 0, actual value bs
# 6633) Predicted value 0, actual value bs
# 6634) Predicted value 0, actual value bs
# 6635) Predicted value 0, actual value bs
# 6636) Predicted value 0, actual value conspiracy
# 6637) Predicted value 0, actual value conspiracy
# 6638) Predicted value 0, actual value conspiracy
# 6639) Predicted value 0, actual value conspiracy
# 6640) Predicted value 0, actual value conspiracy
# 6641) Predicted value 0, actual value bs
# 6642) Predicted value 0, actual value bs
# 6643) Predicted value 0, actual value bs
# 6644) Predicted value 0, actual value bs
# 6645) Predicted value 0, actual value bs
# 6646) Predicted value 0, actual value bs
# 6647) Predicted value 0, actual value bs
# 6648) Predicted value 0, actual value bs
# 6649) Predicted value 0, actual value bs
# 6650) Predicted value 0, actual value bs
# 6651) Predicted value 0, actual value bs
# 6652) Predicted value 0, actual value bs
# 6653) Predicted value 0, actual value bs
# 6654) Predicted value 0, actual value bs
# 6655) Predicted value 0, actual value bs
# 6656) Predicted value 0, actual value bs
# 6657) Predicted value 0, actual value bs
# 6658) Predicted value 0, actual value bs
# 6659) Predicted value 0, actual value bs
# 6660) Predicted value 0, actual value bs
# 6661) Predicted value 0, actual value bs
# 6662) Predicted value 0, actual value bs
# 6663) Predicted value 0, actual value bs
# 6664) Predicted value 0, actual value bs
# 6665) Predicted value 0, actual value bs
# 6666) Predicted value 0, actual value bs
# 6667) Predicted value 0, actual value bs
# 6668) Predicted value 0, actual value bs
# 6669) Predicted value 0, actual value bs
# 6670) Predicted value 0, actual value bs
# 6671) Predicted value 0, actual value bs
# 6672) Predicted value 0, actual value bs
# 6673) Predicted value 0, actual value bs
# 6674) Predicted value 0, actual value bs
# 6675) Predicted value 0, actual value bs
# 6676) Predicted value 0, actual value bs
# 6677) Predicted value 0, actual value bs
# 6678) Predicted value 0, actual value bs
# 6679) Predicted value 0, actual value bs
# 6680) Predicted value 0, actual value bs
# 6681) Predicted value 0, actual value bs
# 6682) Predicted value 0, actual value bs
# 6683) Predicted value 0, actual value bs
# 6684) Predicted value 0, actual value bs
# 6685) Predicted value 0, actual value bs
# 6686) Predicted value 0, actual value bs
# 6687) Predicted value 0, actual value bs
# 6688) Predicted value 0, actual value bs
# 6689) Predicted value 0, actual value bs
# 6690) Predicted value 0, actual value bs
# 6691) Predicted value 0, actual value bs
# 6692) Predicted value 0, actual value bs
# 6693) Predicted value 0, actual value bs
# 6694) Predicted value 0, actual value bs
# 6695) Predicted value 0, actual value bs
# 6696) Predicted value 0, actual value bs
# 6697) Predicted value 0, actual value bs
# 6698) Predicted value 0, actual value bs
# 6699) Predicted value 0, actual value bs
# 6700) Predicted value 0, actual value bs
# 6701) Predicted value 0, actual value bs
# 6702) Predicted value 0, actual value bs
# 6703) Predicted value 0, actual value bs
# 6704) Predicted value 0, actual value bs
# 6705) Predicted value 0, actual value bs
# 6706) Predicted value 0, actual value bs
# 6707) Predicted value 0, actual value bs
# 6708) Predicted value 0, actual value bs
# 6709) Predicted value 0, actual value bs
# 6710) Predicted value 0, actual value bs
# 6711) Predicted value 0, actual value bs
# 6712) Predicted value 0, actual value bs
# 6713) Predicted value 0, actual value bs
# 6714) Predicted value 0, actual value bs
# 6715) Predicted value 0, actual value bs
# 6716) Predicted value 0, actual value bs
# 6717) Predicted value 0, actual value bs
# 6718) Predicted value 0, actual value bs
# 6719) Predicted value 1, actual value bs
# 6720) Predicted value 1, actual value bs
# 6721) Predicted value 1, actual value bs
# 6722) Predicted value 1, actual value bs
# 6723) Predicted value 1, actual value bs
# 6724) Predicted value 1, actual value bs
# 6725) Predicted value 1, actual value bs
# 6726) Predicted value 1, actual value bs
# 6727) Predicted value 1, actual value bs
# 6728) Predicted value 1, actual value bs
# 6729) Predicted value 1, actual value bs
# 6730) Predicted value 1, actual value bs
# 6731) Predicted value 1, actual value bs
# 6732) Predicted value 1, actual value bs
# 6733) Predicted value 1, actual value bs
# 6734) Predicted value 1, actual value bs
# 6735) Predicted value 1, actual value bs
# 6736) Predicted value 1, actual value bs
# 6737) Predicted value 1, actual value bs
# 6738) Predicted value 1, actual value bs
# 6739) Predicted value 1, actual value bs
# 6740) Predicted value 1, actual value bs
# 6741) Predicted value 1, actual value bs
# 6742) Predicted value 1, actual value bs
# 6743) Predicted value 1, actual value bs
# 6744) Predicted value 1, actual value bs
# 6745) Predicted value 1, actual value bs
# 6746) Predicted value 1, actual value bs
# 6747) Predicted value 1, actual value bs
# 6748) Predicted value 1, actual value bs
# 6749) Predicted value 1, actual value bs
# 6750) Predicted value 1, actual value bs
# 6751) Predicted value 1, actual value bs
# 6752) Predicted value 1, actual value bs
# 6753) Predicted value 1, actual value bs
# 6754) Predicted value 1, actual value bs
# 6755) Predicted value 1, actual value bs
# 6756) Predicted value 1, actual value bs
# 6757) Predicted value 1, actual value bs
# 6758) Predicted value 1, actual value bs
# 6759) Predicted value 1, actual value bs
# 6760) Predicted value 1, actual value bs
# 6761) Predicted value 1, actual value bs
# 6762) Predicted value 1, actual value bs
# 6763) Predicted value 1, actual value bs
# 6764) Predicted value 1, actual value bs
# 6765) Predicted value 1, actual value bs
# 6766) Predicted value 1, actual value bs
# 6767) Predicted value 1, actual value bs
# 6768) Predicted value 1, actual value bs
# 6769) Predicted value 1, actual value bs
# 6770) Predicted value 1, actual value bs
# 6771) Predicted value 1, actual value bs
# 6772) Predicted value 1, actual value bs
# 6773) Predicted value 1, actual value bs
# 6774) Predicted value 1, actual value bs
# 6775) Predicted value 1, actual value bs
# 6776) Predicted value 1, actual value bs
# 6777) Predicted value 1, actual value bs
# 6778) Predicted value 1, actual value bs
# 6779) Predicted value 1, actual value bs
# 6780) Predicted value 1, actual value bs
# 6781) Predicted value 1, actual value bs
# 6782) Predicted value 1, actual value bs
# 6783) Predicted value 1, actual value bs
# 6784) Predicted value 1, actual value bs
# 6785) Predicted value 1, actual value bs
# 6786) Predicted value 1, actual value bs
# 6787) Predicted value 1, actual value bs
# 6788) Predicted value 1, actual value bs
# 6789) Predicted value 1, actual value bs
# 6790) Predicted value 1, actual value bs
# 6791) Predicted value 1, actual value bs
# 6792) Predicted value 1, actual value bs
# 6793) Predicted value 1, actual value bs
# 6794) Predicted value 1, actual value bs
# 6795) Predicted value 1, actual value bs
# 6796) Predicted value 1, actual value bs
# 6797) Predicted value 1, actual value bs
# 6798) Predicted value 1, actual value bs
# 6799) Predicted value 1, actual value bs
# 6800) Predicted value 1, actual value bs
# 6801) Predicted value 1, actual value bs
# 6802) Predicted value 1, actual value bs
# 6803) Predicted value 1, actual value bs
# 6804) Predicted value 1, actual value bs
# 6805) Predicted value 1, actual value bs
# 6806) Predicted value 1, actual value bs
# 6807) Predicted value 1, actual value bs
# 6808) Predicted value 1, actual value bs
# 6809) Predicted value 1, actual value bs
# 6810) Predicted value 1, actual value bs
# 6811) Predicted value 1, actual value bs
# 6812) Predicted value 1, actual value bs
# 6813) Predicted value 1, actual value bs
# 6814) Predicted value 1, actual value bs
# 6815) Predicted value 1, actual value bs
# 6816) Predicted value 1, actual value bs
# 6817) Predicted value 1, actual value bs
# bias 1 118
# bias 0 23
# bs 1 3372
# bs 0 2566
# consp 1 243
# consp 0 87
# FAKE count 15
# FAKE 1 15
# FAKE 0 0

# %%
plt.plot(range(2,20),wcss)
plt.title('The Elbow Method Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition

number_of_clusters = 2

reduced_data = decomposition.PCA(n_components=4).fit_transform(df_test)

# Instantiate Kmeans
km = KMeans(n_clusters=number_of_clusters)
clusts = km.fit_predict(reduced_data)



#Plot the clusters obtained using k means
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(reduced_data[:, 0],reduced_data[:, 1], reduced_data[:, 2],
                     c=clusts,s=20, cmap='winter', alpha=0.1)
scatter = ax.scatter(km.cluster_centers_[:, 3],
            km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 2],
            s = 250,
            marker='o',
            c='red',
            label='centroids')


ax.legend()
plt.show()

print(silhouette_score(reduced_data, clusts))

# %%
import sklearn

# Check version
print(sklearn.__version__)

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering


def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)


# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=700000, n_clusters=None)

model = model.fit(df_test)
plt.figure(figsize=(15,4))
plt.title('Hierarchical Clustering Dendrogram')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

print(model.n_clusters_)

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

labels_true = df_test["type"]

X = StandardScaler().fit_transform(df_test)

db = DBSCAN(eps=0.9, min_samples=100).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels))

# #############################################################################
# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs


# #############################################################################
# Compute clustering with MeanShift

# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(X, quantile=0.99, n_samples=None)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)

# #############################################################################
# Plot result
import matplotlib.pyplot as plt
from itertools import cycle

plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
from itertools import cycle
from time import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

from sklearn.cluster import Birch
from sklearn.datasets import make_blobs

birch_model = Birch(n_clusters=2)

# Use all colors that matplotlib provides by default.
colors_ = cycle(colors.cnames.keys())

fig = plt.figure(figsize=(12, 4))
fig.subplots_adjust(left=0.04, right=0.98, bottom=0.1, top=0.9)

birch_model.fit(X)

    # Plot result
labels = birch_model.labels_
centroids = birch_model.subcluster_centers_
n_clusters = np.unique(labels).size
print("n_clusters : %d" % n_clusters)

ax = fig.add_subplot(1, 3, 1)
for this_centroid, k, col in zip(centroids, range(n_clusters), colors_):
    mask = labels == k
    ax.scatter(X[mask, 0], X[mask, 1],c='w', edgecolor=col, marker='.', alpha=0.5)
    if birch_model.n_clusters is None:
        ax.scatter(this_centroid[0], this_centroid[1], marker='+',c='k', s=25)
ax.set_ylim([-2, 2])
ax.set_xlim([-1, 13])
ax.set_autoscaley_on(False)
ax.set_title('Birch')
